# %% [markdown]
# | File | BPM Bandpass | Sigma Bandpass | BPM Alternative | Sigma Alternative | Compatibility |
# |--------|--------------|----------------|-----------------|-------------------|---------------|
# | 0      | 75.06 ± 0.15 | 2.49 ± 0.15    | 74.19 ± 0.63    | 5.0 ± 0.63        | -             |
# | 1      | 75.11 ± 0.27 | 3.64 ± 0.27    | 75.0 ± 0.41     | 5.0 ± 0.41        | -             |
# | 2      | 75.89 ± 0.24 | 4.0 ± 0.24     | 75.0 ± 0.41     | 5.0 ± 0.41        | -             |
# | 3      | 76.27 ± 0.4  | 3.83 ± 0.4     | 75.0 ± 0.41     | 5.0 ± 0.41        | -             |
# | 4      | 78.88 ± 0.36 | 3.75 ± 0.36    | 71.64 ± 0.25    | 2.64 ± 0.25       | 1.58          |
# | 5      | 76.15 ± 0.3  | 3.88 ± 0.3     | 75.0 ± 0.41     | 5.0 ± 0.41        | 0.18          |

# %% [markdown]
# | Metodo | Total Number of Acquisition | Acquisition after cut | Absolout time(s) |
# |--------|-----------------------------|------------|----------------|
# | 0      | 14306                       | 13177      | 75.0    |
# | 1      | 7999                        | 6249       | 92.0    |
# | 2      | 11078                       | 9425       | 117.0   |
# | 3      | 6109                        | 5234       | 69.0    |
# | 4      | 12400                       | 11900      | 148.0    |
# | 5      | 8756                        | 7922       | 99.0    |
